# %% [markdown]
# <a href="https://colab.research.google.com/github/anitha200/python-new/blob/module-4/Copy_of_Matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib

print(matplotlib.__version__)
# Out:
# 3.2.2

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([0, 10])
ypoints = np.array([0, 350])

plt.plot(xpoints, ypoints)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([0, 8])
ypoints = np.array([5, 10])

plt.plot(xpoints, ypoints)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([0, 8, 4, 15])

plt.plot(ypoints, marker = 'o')
plt.show()

# %%
##doted line
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([0, 9, 1, 10])

plt.plot(ypoints, linestyle = 'dotted')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, linestyle = 'dashed')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, ls = ':')
plt.show()

# %%
##line color
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([2, 7, 2, 16])

plt.plot(ypoints, color = 'y')
plt.show()

# %%
##Matplotlib Plotting
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([16, 17])
ypoints = np.array([2, 10])

plt.plot(xpoints, ypoints)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([16, 17])
ypoints = np.array([2, 13])

plt.plot(xpoints, ypoints, 'o')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([1, 6, 7, 8])
ypoints = np.array([17, 8, 1, 20])

plt.plot(xpoints, ypoints)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([2, 19, 1, 10, 2, 7])

plt.plot(ypoints)
plt.show()

# %%
##markers
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([2, 7, 2, 16])

plt.plot(ypoints, marker = 'o')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([2, 7, 2, 17])

plt.plot(ypoints, 'o:r')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([2, 7, 2, 10])

plt.plot(ypoints, marker = 'o', ms = 30)
plt.show()

# %%
##marker color
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([2, 7, 2, 10])

plt.plot(ypoints, marker = 'o', ms = 20, mec = 'r')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([2, 8, 2, 10])

plt.plot(ypoints, marker = 'o', ms = 20, mfc = 'r')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([2, 8, 4, 10])

plt.plot(ypoints, marker = 'o', ms = 20, mec = 'y', mfc = 'y')
plt.show()

# %%
...
plt.plot(ypoints, marker = 'o', ms = 20, mec = '#4CAF50', mfc = '#4CAF50')
...
# Out:
# Ellipsis

# %%
...
plt.plot(ypoints, marker = 'o', ms = 20, mec = 'hotpink', mfc = 'hotpink')
...
# Out:
# Ellipsis

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3, 8, 1, 10])
plt.plot(ypoints, c = '#4CAF50')
plt.show()

# %%
...
plt.plot(ypoints, c = 'hotpink')
...
# Out:
# Ellipsis

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([2, 8, 2, 10])

plt.plot(ypoints, linewidth = '29')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

y1 = np.array([4, 8, 1, 2])
y2 = np.array([6, 7, 1, 5])

plt.plot(y1)
plt.plot(y2)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x1 = np.array([0, 1, 2, 3])
y1 = np.array([3, 8, 1, 10])
x2 = np.array([0, 1, 2, 3])
y2 = np.array([6, 2, 7, 11])

plt.plot(x1, y1, x2, y2)
plt.show()

# %%
##Matplotlib Labels and Title
import numpy as np
import matplotlib.pyplot as plt

x = np.array([80, 85, 90, 95, 100, 169, 110, 147, 120, 175])
y = np.array([240, 250, 460, 270, 280, 290, 300, 540, 320, 230])

plt.plot(x, y)

plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")

plt.show()

# %%
##grid lines
import numpy as np
import matplotlib.pyplot as plt

x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 170])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 360])

plt.title("Sports Watch Data")
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")

plt.plot(x, y)

plt.grid()

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.plot(x, y)

plt.title("Sports Watch Data")
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.title("Sports Watch Data")
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")

plt.plot(x, y)

plt.grid(color = 'green', linestyle = '--', linewidth = 0.5)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

#plot 1:
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(1, 2, 1)
plt.plot(x,y)

#plot 2:
x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(1, 2, 2)
plt.plot(x,y)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

#plot 1:
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 1, 1)
plt.plot(x,y)

#plot 2:
x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 1, 2)
plt.plot(x,y)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.array([45, 25, 25, 10])

plt.pie(y)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.title("Sports Watch Data")
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")

plt.plot(x, y)

plt.grid(axis = 'y')

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.array([25, 45, 25, 10])
mylabels = ["maths", "phy", "Chem", "bio"]

plt.pie(y, labels = mylabels)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.array([45, 25, 25, 15])
mylabels = ["maths", "Bio", "chem", "phy"]
myexplode = [0.2, 0.3, 0.2, 0.1]

plt.pie(y, labels = mylabels, explode = myexplode)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.array([35, 25, 25, 15])
mylabels = ["maths", "Bio", "Chem", "phy"]
mycolors = ["yellow", "hotpink", "b", "#4CAF50"]

plt.pie(y, labels = mylabels, colors = mycolors)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.array([15, 25, 25, 35])
mylabels = ["maths", "Bio", "chem", "phy"]

plt.pie(y, labels = mylabels)
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.array([35, 35, 25, 15])
mylabels = ["phy", "Bio", "Chem", "maths"]

plt.pie(y, labels = mylabels)
plt.legend(title = "Four Fruits:")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.random.normal(170, 10, 150)

plt.hist(x)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array(["A", "B", "C", "D"])
y = np.array([5, 9, 1, 10])

plt.bar(x,y)
plt.show()

# %%
##scatter
import matplotlib.pyplot as plt
import numpy as np

#day one, the age and speed of 13 cars:
x = np.array([9,7,8,4,2,17,12,9,14,11,12,17,16])
y = np.array([99,98,87,88,111,86,103,87,94,99,91,85,86])
plt.scatter(x, y)

#day two, the age and speed of 15 cars:
x = np.array([12,20,18,1,15,8,12,9,7,3,11,24,7,14,12])
y = np.array([100,105,84,105,90,99,90,95,94,100,97,112,95,80,85])
plt.scatter(x, y)

plt.show()

# %%
##2 plots
import matplotlib.pyplot as plt
import numpy as np

x = np.array([15,9,8,17,2,27,2,9,4,11,12,9,8])
y = np.array([99,86,87,88,111,86,103,87,94,78,100,85,86])

plt.scatter(x, y)
plt.show()

# %%
##own color
import matplotlib.pyplot as plt
import numpy as np

x = np.array([10,17,28,15,20,17,2,9,4,19,12,9,16])
y = np.array([99,86,87,88,111,86,103,87,94,78,100,85,86])
plt.scatter(x, y, color = 'yellow')

x = np.array([12,20,8,1,15,8,12,9,7,3,11,40,7,14,12])
y = np.array([100,105,84,105,90,99,90,95,94,100,79,112,91,80,85])
plt.scatter(x, y, color = 'red')

plt.show()

# %%
##dot each color
import matplotlib.pyplot as plt
import numpy as np

x = np.array([9,7,8,7,2,17,2,9,4,11,12,19,6])
y = np.array([99,86,87,88,111,86,103,87,94,100,110,95,86])
colors = np.array(["black","green","blue","yellow","pink","black","orange","purple","beige","brown","gray","cyan","blue"])

plt.scatter(x, y, c=colors)

plt.show()

# %%
##acual color map
import matplotlib.pyplot as plt
import numpy as np

x = np.array([15,7,8,17,2,17,2,9,4,13,12,20,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,100,88,86])
colors = np.array([0, 10, 25, 30, 40, 45, 50, 55, 60, 65, 80, 90, 100])

plt.scatter(x, y, c=colors, cmap='viridis')

plt.colorbar()

plt.show()

# %%
##size
import matplotlib.pyplot as plt
import numpy as np

x = np.array([15,7,8,7,22,17,20,19,40,11,12,19,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,100,85,86])
sizes = np.array([20,50,100,200,500,1000,60,90,10,300,600,800,75])

plt.scatter(x, y, s=sizes)

plt.show()

# %%
##alpha
import matplotlib.pyplot as plt
import numpy as np

x = np.array([15,7,8,17,22,17,2,9,4,11,12,19,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,100,85,86])
sizes = np.array([20,50,100,200,500,1000,60,90,10,300,600,800,175])

plt.scatter(x, y, s=sizes, alpha=0.5)

plt.show()

# %%
##comine color and size
import matplotlib.pyplot as plt
import numpy as np

x = np.random.randint(80, size=(80))
y = np.random.randint(80, size=(80))
colors = np.random.randint(80, size=(80))
sizes = 10 * np.random.randint(80, size=(80))

plt.scatter(x, y, c=colors, s=sizes, alpha=0.5, cmap='nipy_spectral')

plt.colorbar()

plt.show()

# %%
##horizontal bar
import matplotlib.pyplot as plt
import numpy as np

x = np.array(["A", "B", "C", "D"])
y = np.array([6, 8, 13, 15])

plt.barh(x, y)
plt.show()

# %%
##bar color
import matplotlib.pyplot as plt
import numpy as np

x = np.array(["A", "B", "C", "D"])
y = np.array([13, 8, 11, 10])

plt.bar(x, y, color = "yellow")
plt.show()

# %%
##color names
import matplotlib.pyplot as plt
import numpy as np

x = np.array(["A", "B", "C", "D"])
y = np.array([12, 8, 15, 10])

plt.bar(x, y, color = "hotpink")
plt.show()

# %%
##bar width
import matplotlib.pyplot as plt
import numpy as np

x = np.array(["A", "B", "C", "D"])
y = np.array([12, 15, 10, 10])

plt.bar(x, y, width = 0.3)
plt.show()

# %%
##bar height
import matplotlib.pyplot as plt
import numpy as np

x = np.array(["A", "B", "C", "D"])
y = np.array([13, 15, 12, 10])

plt.barh(x, y, height = 0.3)
plt.show()

# %%
##6 plots
import matplotlib.pyplot as plt
import numpy as np

x = np.array([0, 1, 2, 3])
y = np.array([13, 8, 5, 10])

plt.subplot(2, 3, 1)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 3, 2)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([7, 8, 5, 10])

plt.subplot(2, 3, 3)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 3, 4)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([13, 8, 11, 10])

plt.subplot(2, 3, 5)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 50])

plt.subplot(2, 3, 6)
plt.plot(x,y)

plt.show()

# %%
##title
import matplotlib.pyplot as plt
import numpy as np

#plot 1:
x = np.array([0, 1, 2, 3])
y = np.array([5, 8, 6, 10])

plt.subplot(1, 2, 1)
plt.plot(x,y)
plt.title("maths")

#plot 2:
x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(1, 2, 2)
plt.plot(x,y)
plt.title("chem")

plt.show()

# %%
##sup title

import matplotlib.pyplot as plt
import numpy as np

#plot 1:
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(1, 2, 1)
plt.plot(x,y)
plt.title("maths")

#plot 2:
x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(1, 2, 2)
plt.plot(x,y)
plt.title("phy")

plt.suptitle("SUBJECTS")
plt.show()
